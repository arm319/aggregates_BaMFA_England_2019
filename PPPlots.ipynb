# %%
# Iterate through the DataFrame and print HDI 95 values
for idx, row in df.iterrows():
    hdi_95_prior = norm.interval(0.95, loc=row['prior mean'], scale=row['prior sd'])
    hdi_95_posterior = norm.interval(0.95, loc=row['mean'], scale=row['sd'])
    
    print(f"{row['name']} - Prior HDI 95%: ({hdi_95_prior[0]:.0f}, {hdi_95_prior[1]:.0f}), Posterior HDI 95%: ({hdi_95_posterior[0]:.0f}, {hdi_95_posterior[1]:.0f})")
# Out:
# Gravel_md - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (1862, 2771)
# Crushed_Rock_ex - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-3158, 223)
# Asphalt_Sand - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-5356, -639)
# Concreting_Gravel - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-14239, 468)
# Land_Won_Sand - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-200, 778)
# Aggregate_use - Prior HDI 95%: (-105117, 177117), Posterior HDI 95%: (-21667, 2998)
# Gravel_for_fill - Prior HDI 95%: (-23526, 39640), Posterior HDI 95%: (2789, 12463)
# Sand_for_fill - Prior HDI 95%: (-15683, 26425), Posterior HDI 95%: (-688, 9206)
# Buildings_Gravel - Prior HDI 95%: (-7387, 12447), Posterior HDI 95%: (-719, 26939)
# Crushed_Rock_td - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (4145, 15252)
# Asphalt_Gravel - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (7071, 23986)
# Asphalt_Crushed_Rock - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (12497, 68740)
# Recycled_Processing/Production_Waste - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (26003, 37837)
# Sand_ex - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (9175, 13295)
# Buildings_Sand - Prior HDI 95%: (-4926, 8300), Posterior HDI 95%: (-593, 596)
# Buildings_Crushed_Rock - Prior HDI 95%: (-23024, 38794), Posterior HDI 95%: (-1199, 39538)
# Overburden_and_interburden_owp - Prior HDI 95%: (-13140, 22140), Posterior HDI 95%: (27, 1509)
# Recycled_Deconstruction_Material - Prior HDI 95%: (-31560, 43702), Posterior HDI 95%: (618, 2091)
# Mortar_Sand - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (269, 1863)
# Deconstruction - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-9549, 19378)
# Manufacturing_Waste_owp - Prior HDI 95%: (-730, 1230), Posterior HDI 95%: (-5119, 7101)
# Secondary_Aggregates_pr - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-5211, 7203)
# Scalpings_and_Fines_owp - Prior HDI 95%: (-730, 1230), Posterior HDI 95%: (-5178, 7271)
# Marine_Dredged_Outside_England_Waters - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-5153, 7117)
# Gravel_ex - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-5183, 7180)
# Terrestrial - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-5245, 7251)
# Demolition - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-5157, 7189)
# Terrestrial_Crushed_Rock_ex - Prior HDI 95%: (-269331, 453809), Posterior HDI 95%: (47504, 99731)
# Terrestrial_Sand_ex - Prior HDI 95%: (-51531, 86827), Posterior HDI 95%: (12375, 31280)
# Terrestrial_Gravel_ex - Prior HDI 95%: (-77296, 130240), Posterior HDI 95%: (12513, 32786)
# Marine_Sand_md - Prior HDI 95%: (-13981, 23557), Posterior HDI 95%: (598, 15757)
# Marine_Gravel_md - Prior HDI 95%: (-20971, 35335), Posterior HDI 95%: (2100, 18653)
# Crushed_Rock_ex_Crushed_Rock_pr - Prior HDI 95%: (-249117, 419749), Posterior HDI 95%: (29475, 47312)
# Crushed_Rock_ex_Crushed_Rock_for_fill - Prior HDI 95%: (-29170, 49150), Posterior HDI 95%: (-5030, 40973)
# Crushed_Rock_ex_Overburden_and_interburden_owp - Prior HDI 95%: (-19753, 33283), Posterior HDI 95%: (7427, 27076)
# Sand_ex_Sand_pr - Prior HDI 95%: (-47563, 80141), Posterior HDI 95%: (6675, 23954)
# Sand_ex_Sand_for_fill - Prior HDI 95%: (-5554, 9358), Posterior HDI 95%: (908, 7581)
# Sand_ex_Overburden_and_interburden_owp - Prior HDI 95%: (-2958, 4984), Posterior HDI 95%: (579, 3979)
# Gravel_ex_Gravel_pr - Prior HDI 95%: (-71346, 120214), Posterior HDI 95%: (2914, 20516)
# Gravel_ex_Gravel_for_fill - Prior HDI 95%: (-8333, 14041), Posterior HDI 95%: (1918, 12632)
# Gravel_ex_Overburden_and_interburden_owp - Prior HDI 95%: (-4435, 7473), Posterior HDI 95%: (1006, 6293)
# Sand_md_Sand_pr - Prior HDI 95%: (-12903, 21741), Posterior HDI 95%: (-741, 14433)
# Sand_md_Sand_for_fill - Prior HDI 95%: (-479, 807), Posterior HDI 95%: (61, 651)
# Sand_md_Overburden_and_interburden_owp - Prior HDI 95%: (-1267, 2135), Posterior HDI 95%: (256, 1710)
# Gravel_md_Gravel_pr - Prior HDI 95%: (-19356, 32614), Posterior HDI 95%: (59, 16559)
# Gravel_md_Gravel_for_fill - Prior HDI 95%: (-715, 1205), Posterior HDI 95%: (99, 986)
# Gravel_md_Overburden_and_interburden_owp - Prior HDI 95%: (-1901, 3203), Posterior HDI 95%: (406, 2618)
# Sand_pr_Concreting_Sand - Prior HDI 95%: (-39612, 66744), Posterior HDI 95%: (8649, 15437)
# Sand_pr_Asphalt_Sand - Prior HDI 95%: (-1475, 2485), Posterior HDI 95%: (373, 659)
# Sand_pr_Mortar_Sand - Prior HDI 95%: (-11680, 19680), Posterior HDI 95%: (1331, 2645)
# Sand_pr_Sand_for_fill - Prior HDI 95%: (-1837, 3095), Posterior HDI 95%: (287, 2594)
# Sand_pr_Aggregate_use - Prior HDI 95%: (-8415, 14179), Posterior HDI 95%: (1148, 4652)
# Sand_pr_Non-aggregate_use - Prior HDI 95%: (-3183, 5363), Posterior HDI 95%: (429, 1775)
# Sand_pr_Scalpings_and_Fines_owp - Prior HDI 95%: (-1285, 2165), Posterior HDI 95%: (22, 265)
# Sand_pr_Land_Won_Sand - Prior HDI 95%: (-3881, 6539), Posterior HDI 95%: (237, 1753)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-282, 1014)
# Sand_pr_Marine_Dredged_Sand - Prior HDI 95%: (-1661, 2799), Posterior HDI 95%: (170, 887)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-280, 1004)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-22, 83)
# Gravel_pr_Concreting_Gravel - Prior HDI 95%: (-23976, 40398), Posterior HDI 95%: (6031, 10847)
# Gravel_pr_Asphalt_Gravel - Prior HDI 95%: (-491, 827), Posterior HDI 95%: (120, 220)
# Gravel_pr_Gravel_for_fill - Prior HDI 95%: (-2753, 4639), Posterior HDI 95%: (527, 4127)
# Gravel_pr_Aggregate_use - Prior HDI 95%: (-12626, 21274), Posterior HDI 95%: (2027, 7328)
# Gravel_pr_Non-aggregate_use - Prior HDI 95%: (-4777, 8049), Posterior HDI 95%: (710, 2694)
# Gravel_pr_Scalpings_and_Fines_owp - Prior HDI 95%: (-1930, 3252), Posterior HDI 95%: (34, 393)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-289, 1083)
# Gravel_pr_Land_Won_Gravel - Prior HDI 95%: (-5819, 9805), Posterior HDI 95%: (261, 2270)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-299, 1095)
# Gravel_pr_Marine_Dredged_Gravel - Prior HDI 95%: (-2494, 4202), Posterior HDI 95%: (231, 1273)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-22, 84)
# Crushed_Rock_pr_Concreting_Crushed_Rock - Prior HDI 95%: (-24644, 41524), Posterior HDI 95%: (6032, 10985)
# Crushed_Rock_pr_Asphalt_Crushed_Rock - Prior HDI 95%: (-7817, 13171), Posterior HDI 95%: (1885, 3457)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-193, 914)
# Crushed_Rock_pr_Crushed_Rock_for_fill - Prior HDI 95%: (-8877, 14957), Posterior HDI 95%: (59, 13713)
# Crushed_Rock_pr_Aggregate_use - Prior HDI 95%: (-39346, 66296), Posterior HDI 95%: (9297, 18791)
# Crushed_Rock_pr_Non-aggregate_use - Prior HDI 95%: (-14886, 25082), Posterior HDI 95%: (3485, 6983)
# Crushed_Rock_pr_Scalpings_and_Fines_owp - Prior HDI 95%: (-6012, 10130), Posterior HDI 95%: (209, 1110)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-22, 82)
# Secondary_Aggregates_pr_Concreting_Sand - Prior HDI 95%: (-1673, 2819), Posterior HDI 95%: (170, 873)
# Secondary_Aggregates_pr_Asphalt_Sand - Prior HDI 95%: (-61, 103), Posterior HDI 95%: (7, 36)
# Secondary_Aggregates_pr_Mortar_Sand - Prior HDI 95%: (-493, 831), Posterior HDI 95%: (25, 145)
# Secondary_Aggregates_pr_Aggregate_use - Prior HDI 95%: (-2552, 4300), Posterior HDI 95%: (292, 1515)
# Secondary_Aggregates_pr_Non-aggregate_use - Prior HDI 95%: (-966, 1628), Posterior HDI 95%: (111, 565)
# Secondary_Aggregates_pr_Scalpings_and_Fines_owp - Prior HDI 95%: (-391, 659), Posterior HDI 95%: (4, 82)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-23, 85)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-22, 132)
# C&D_Waste_pr_Concreting_Sand - Prior HDI 95%: (-14506, 24442), Posterior HDI 95%: (2021, 7248)
# C&D_Waste_pr_Concreting_Gravel - Prior HDI 95%: (-9793, 16501), Posterior HDI 95%: (1356, 5209)
# C&D_Waste_pr_Concreting_Crushed_Rock - Prior HDI 95%: (-10068, 16964), Posterior HDI 95%: (1507, 5437)
# C&D_Waste_pr_Asphalt_Sand - Prior HDI 95%: (-540, 910), Posterior HDI 95%: (79, 298)
# C&D_Waste_pr_Asphalt_Gravel - Prior HDI 95%: (-199, 335), Posterior HDI 95%: (30, 109)
# C&D_Waste_pr_Asphalt_Crushed_Rock - Prior HDI 95%: (-3194, 5382), Posterior HDI 95%: (471, 1716)
# C&D_Waste_pr_Mortar_Sand - Prior HDI 95%: (-4275, 7203), Posterior HDI 95%: (291, 1186)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-194, 922)
# C&D_Waste_pr_Sand_for_fill - Prior HDI 95%: (-750, 1264), Posterior HDI 95%: (102, 1037)
# C&D_Waste_pr_Gravel_for_fill - Prior HDI 95%: (-1124, 1894), Posterior HDI 95%: (154, 1586)
# C&D_Waste_pr_Crushed_Rock_for_fill - Prior HDI 95%: (-3624, 6106), Posterior HDI 95%: (-67, 5292)
# C&D_Waste_pr_Aggregate_use - Prior HDI 95%: (-22113, 37259), Posterior HDI 95%: (6193, 8994)
# C&D_Waste_pr_Non-aggregate_use - Prior HDI 95%: (-8366, 14096), Posterior HDI 95%: (2336, 3396)
# C&D_Waste_pr_Scalpings_and_Fines_owp - Prior HDI 95%: (-3378, 5692), Posterior HDI 95%: (72, 674)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-23, 84)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (3345, 12594)
# Concreting_Sand_Buildings_Sand - Prior HDI 95%: (-15026, 25318), Posterior HDI 95%: (4172, 13811)
# Concreting_Sand_Manufacturing_Waste_lf - Prior HDI 95%: (-260, 438), Posterior HDI 95%: (-62, 437)
# Concreting_Sand_Manufacturing_Waste_owp - Prior HDI 95%: (-377, 635), Posterior HDI 95%: (-90, 417)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-478, 7920)
# Concreting_Gravel_Buildings_Gravel - Prior HDI 95%: (-22536, 37972), Posterior HDI 95%: (3280, 12356)
# Concreting_Gravel_Manufacturing_Waste_lf - Prior HDI 95%: (-391, 659), Posterior HDI 95%: (-89, 631)
# Concreting_Gravel_Manufacturing_Waste_owp - Prior HDI 95%: (-564, 950), Posterior HDI 95%: (-117, 484)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-986, 8198)
# Concreting_Crushed_Rock_Buildings_Crushed_Rock - Prior HDI 95%: (-70242, 118354), Posterior HDI 95%: (9667, 20401)
# Concreting_Crushed_Rock_Manufacturing_Waste_lf - Prior HDI 95%: (-196, 330), Posterior HDI 95%: (-46, 320)
# Concreting_Crushed_Rock_Manufacturing_Waste_owp - Prior HDI 95%: (-1758, 2962), Posterior HDI 95%: (-172, 601)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-1080, 7719)
# Concreting_C&D_Buildings_Crushed_Rock - Prior HDI 95%: (-44033, 74193), Posterior HDI 95%: (-3246, 23223)
# Concreting_C&D_Manufacturing_Waste_lf - Prior HDI 95%: (-123, 207), Posterior HDI 95%: (-31, 200)
# Concreting_C&D_Manufacturing_Waste_owp - Prior HDI 95%: (-1101, 1855), Posterior HDI 95%: (-163, 583)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (149, 1318)
# Asphalt_Sand_Manufacturing_Waste_lf - Prior HDI 95%: (-9, 15), Posterior HDI 95%: (-2, 14)
# Asphalt_Sand_Manufacturing_Waste_owp - Prior HDI 95%: (-79, 133), Posterior HDI 95%: (-19, 116)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-103, 795)
# Asphalt_Gravel_Manufacturing_Waste_lf - Prior HDI 95%: (-15, 25), Posterior HDI 95%: (-4, 24)
# Asphalt_Gravel_Manufacturing_Waste_owp - Prior HDI 95%: (-120, 202), Posterior HDI 95%: (-31, 162)
# 0 - Prior HDI 95%: (nan, nan), Posterior HDI 95%: (3431, 5705)
# Asphalt_Crushed_Rock_Manufacturing_Waste_lf - Prior HDI 95%: (-41, 69), Posterior HDI 95%: (-10, 66)
# Asphalt_Crushed_Rock_Manufacturing_Waste_owp - Prior HDI 95%: (-371, 625), Posterior HDI 95%: (-91, 406)
# Mortar_Sand_Buildings_Sand - Prior HDI 95%: (-493, 831), Posterior HDI 95%: (619, 1799)
# Mortar_Sand_Manufacturing_Waste_lf - Prior HDI 95%: (-53, 89), Posterior HDI 95%: (-11, 98)
# Mortar_Sand_Manufacturing_Waste_owp - Prior HDI 95%: (-476, 802), Posterior HDI 95%: (188, 1240)
# Road_Sand_Demolition - Prior HDI 95%: (-4073, 6863), Posterior HDI 95%: (731, 3713)
# Road_Gravel_Demolition - Prior HDI 95%: (-6108, 10292), Posterior HDI 95%: (1108, 5607)
# Road_Crushed_Rock_Demolition - Prior HDI 95%: (-19038, 32078), Posterior HDI 95%: (4210, 18707)
# Railway_ballast_Demolition - Prior HDI 95%: (-307, 517), Posterior HDI 95%: (-50, 551)
# Other_inf_Demolition - Prior HDI 95%: (-49210, 82916), Posterior HDI 95%: (15693, 38032)
# Other_inf_Deconstruction - Prior HDI 95%: (-7601, 12807), Posterior HDI 95%: (591, 1603)
# Buildings_Sand_Demolition - Prior HDI 95%: (-3857, 6499), Posterior HDI 95%: (925, 3958)
# Buildings_Sand_Deconstruction - Prior HDI 95%: (-590, 994), Posterior HDI 95%: (25, 148)
# Buildings_Gravel_Demolition - Prior HDI 95%: (-5787, 9751), Posterior HDI 95%: (1213, 5645)
# Buildings_Gravel_Deconstruction - Prior HDI 95%: (-882, 1486), Posterior HDI 95%: (37, 220)
# Buildings_Crushed_Rock_Demolition - Prior HDI 95%: (-18036, 30390), Posterior HDI 95%: (4289, 18730)
# Buildings_Crushed_Rock_Deconstruction - Prior HDI 95%: (-2751, 4635), Posterior HDI 95%: (123, 680)
# Demolition_C&D_Waste_pr - Prior HDI 95%: (-100384, 169142), Posterior HDI 95%: (23633, 33884)
# Demolition_Concreting_C&D - Prior HDI 95%: (-21012, 35404), Posterior HDI 95%: (32, 27164)
# Demolition_C&D_Waste_lf - Prior HDI 95%: (-40464, 68180), Posterior HDI 95%: (-1192, 39537)
# Deconstruction_Recycled_Deconstruction_Material - Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (1070, 2010)
# Scalpings_and_Fines_owp_Recycled_Processing/Production_Waste - Prior HDI 95%: (-21549, 36309), Posterior HDI 95%: (-64, 204)
# Overburden_and_interburden_owp_Sand_for_fill - Prior HDI 95%: (-4771, 8039), Posterior HDI 95%: (-1120, 7300)
# Overburden_and_interburden_owp_Gravel_for_fill - Prior HDI 95%: (-7157, 12059), Posterior HDI 95%: (-1614, 10651)
# Overburden_and_interburden_owp_Crushed_Rock_for_fill - Prior HDI 95%: (-22308, 37588), Posterior HDI 95%: (-2031, 28337)
# Land_Won_Sand_Concreting_Sand - Prior HDI 95%: (-435, 733), Posterior HDI 95%: (71, 236)
# Land_Won_Sand_Asphalt_Sand - Prior HDI 95%: (-64, 108), Posterior HDI 95%: (9, 37)
# Land_Won_Sand_Mortar_Sand - Prior HDI 95%: (-55, 93), Posterior HDI 95%: (7, 31)
# Land_Won_Gravel_Concreting_Gravel - Prior HDI 95%: (-721, 1215), Posterior HDI 95%: (164, 349)
# Land_Won_Gravel_Asphalt_Gravel - Prior HDI 95%: (-108, 182), Posterior HDI 95%: (16, 62)
# Marine_Dredged_Sand_Concreting_Sand - Prior HDI 95%: (-38, 64), Posterior HDI 95%: (6, 21)
# Marine_Dredged_Sand_Asphalt_Sand - Prior HDI 95%: (-6, 10), Posterior HDI 95%: (1, 3)
# Marine_Dredged_Sand_Mortar_Sand - Prior HDI 95%: (-6, 10), Posterior HDI 95%: (1, 3)
# Marine_Dredged_Gravel_Concreting_Gravel - Prior HDI 95%: (-64, 108), Posterior HDI 95%: (15, 31)
# Marine_Dredged_Gravel_Asphalt_Gravel - Prior HDI 95%: (-9, 15), Posterior HDI 95%: (1, 5)
# Crushed_Rock_td_Concreting_Crushed_Rock - Prior HDI 95%: (-20264, 34144), Posterior HDI 95%: (5513, 8505)
# Crushed_Rock_td_Asphalt_Crushed_Rock - Prior HDI 95%: (-3040, 5122), Posterior HDI 95%: (385, 1644)
# Crushed_Rock_td_Aggregate_Use - Prior HDI 95%: (-2590, 4364), Posterior HDI 95%: (-628, 4224)
# Secondary_Aggregates_Secondary_Aggregates_pr - Prior HDI 95%: (-15563, 26223), Posterior HDI 95%: (1003, 2896)
# Marine_Dredged_Outside_England_Waters_Sand_pr - Prior HDI 95%: (-701, 1181), Posterior HDI 95%: (116, 369)
# Marine_Dredged_Outside_England_Waters_Gravel_pr - Prior HDI 95%: (-1051, 1771), Posterior HDI 95%: (227, 499)

# %%
# Iterate through the DataFrame and print HDI 95 values and 'navigation' numbers
for idx, row in df.iterrows():
    hdi_95_prior = norm.interval(0.95, loc=row['prior mean'], scale=row['prior sd'])
    hdi_95_posterior = norm.interval(0.95, loc=row['mean'], scale=row['sd'])
    
    print(f"{row['name']} - Navigation: {row['navigation']}, Prior HDI 95%: ({hdi_95_prior[0]:.0f}, {hdi_95_prior[1]:.0f}), Posterior HDI 95%: ({hdi_95_posterior[0]:.0f}, {hdi_95_posterior[1]:.0f})")
# Out:
# Gravel_md - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (1868, 2771)
# Crushed_Rock_ex - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-3163, 214)
# Asphalt_Sand - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-5332, -677)
# Concreting_Gravel - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-14167, 416)
# Land_Won_Sand - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-202, 774)
# Aggregate_use - Navigation: 0-0-0-0, Prior HDI 95%: (-105117, 177117), Posterior HDI 95%: (-21801, 2893)
# Gravel_for_fill - Navigation: 0-0-0-0, Prior HDI 95%: (-23526, 39640), Posterior HDI 95%: (2929, 12529)
# Sand_for_fill - Navigation: 0-0-0-0, Prior HDI 95%: (-15683, 26425), Posterior HDI 95%: (-789, 9452)
# Buildings_Gravel - Navigation: 0-0-0-0, Prior HDI 95%: (-7387, 12447), Posterior HDI 95%: (-596, 27328)
# Crushed_Rock_td - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (4065, 15332)
# Asphalt_Gravel - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (7206, 24208)
# Asphalt_Crushed_Rock - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (11245, 72026)
# Recycled_Processing/Production_Waste - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (26091, 37771)
# Sand_ex - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (9170, 13253)
# Buildings_Sand - Navigation: 0-0-0-0, Prior HDI 95%: (-4926, 8300), Posterior HDI 95%: (-575, 579)
# Buildings_Crushed_Rock - Navigation: 0-0-0-0, Prior HDI 95%: (-23024, 38794), Posterior HDI 95%: (-1661, 39358)
# Overburden_and_interburden_owp - Navigation: 0-0-0-0, Prior HDI 95%: (-13140, 22140), Posterior HDI 95%: (22, 1509)
# Recycled_Deconstruction_Material - Navigation: 0-0-0-0, Prior HDI 95%: (-31560, 43702), Posterior HDI 95%: (628, 2096)
# Mortar_Sand - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (270, 1862)
# Deconstruction - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-9624, 19225)
# Manufacturing_Waste_owp - Navigation: 0-0-0-0, Prior HDI 95%: (-730, 1230), Posterior HDI 95%: (-5258, 7173)
# Secondary_Aggregates_pr - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-5183, 7190)
# Scalpings_and_Fines_owp - Navigation: 0-0-0-0, Prior HDI 95%: (-730, 1230), Posterior HDI 95%: (-5194, 7220)
# Marine_Dredged_Outside_England_Waters - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-5130, 7122)
# Gravel_ex - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-5176, 7217)
# Terrestrial - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-5172, 7221)
# Demolition - Navigation: 0-0-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (-5125, 7151)
# Terrestrial_Crushed_Rock_ex - Navigation: 0-2-0-0, Prior HDI 95%: (-269331, 453809), Posterior HDI 95%: (45972, 103068)
# Terrestrial_Sand_ex - Navigation: 0-3-0-0, Prior HDI 95%: (-51531, 86827), Posterior HDI 95%: (10642, 28944)
# Terrestrial_Gravel_ex - Navigation: 0-4-0-0, Prior HDI 95%: (-77296, 130240), Posterior HDI 95%: (10814, 30023)
# Marine_Sand_md - Navigation: 1-5-0-0, Prior HDI 95%: (-13981, 23557), Posterior HDI 95%: (598, 15510)
# Marine_Gravel_md - Navigation: 1-6-0-0, Prior HDI 95%: (-20971, 35335), Posterior HDI 95%: (2189, 17851)
# Crushed_Rock_ex_Crushed_Rock_pr - Navigation: 2-9-0-0, Prior HDI 95%: (-249117, 419749), Posterior HDI 95%: (29435, 47310)
# Crushed_Rock_ex_Crushed_Rock_for_fill - Navigation: 2-31-0-0, Prior HDI 95%: (-29170, 49150), Posterior HDI 95%: (-6797, 44660)
# Crushed_Rock_ex_Overburden_and_interburden_owp - Navigation: 2-41-0-0, Prior HDI 95%: (-19753, 33283), Posterior HDI 95%: (7374, 27060)
# Sand_ex_Sand_pr - Navigation: 3-7-0-0, Prior HDI 95%: (-47563, 80141), Posterior HDI 95%: (4966, 21582)
# Sand_ex_Sand_for_fill - Navigation: 3-29-0-0, Prior HDI 95%: (-5554, 9358), Posterior HDI 95%: (901, 7599)
# Sand_ex_Overburden_and_interburden_owp - Navigation: 3-41-0-0, Prior HDI 95%: (-2958, 4984), Posterior HDI 95%: (568, 3994)
# Gravel_ex_Gravel_pr - Navigation: 4-8-0-0, Prior HDI 95%: (-71346, 120214), Posterior HDI 95%: (1199, 17577)
# Gravel_ex_Gravel_for_fill - Navigation: 4-30-0-0, Prior HDI 95%: (-8333, 14041), Posterior HDI 95%: (1947, 12772)
# Gravel_ex_Overburden_and_interburden_owp - Navigation: 4-41-0-0, Prior HDI 95%: (-4435, 7473), Posterior HDI 95%: (1045, 6289)
# Sand_md_Sand_pr - Navigation: 5-7-0-0, Prior HDI 95%: (-12903, 21741), Posterior HDI 95%: (-722, 14165)
# Sand_md_Sand_for_fill - Navigation: 5-29-0-0, Prior HDI 95%: (-479, 807), Posterior HDI 95%: (61, 655)
# Sand_md_Overburden_and_interburden_owp - Navigation: 5-41-0-0, Prior HDI 95%: (-1267, 2135), Posterior HDI 95%: (236, 1731)
# Gravel_md_Gravel_pr - Navigation: 6-8-0-0, Prior HDI 95%: (-19356, 32614), Posterior HDI 95%: (168, 15743)
# Gravel_md_Gravel_for_fill - Navigation: 6-30-0-0, Prior HDI 95%: (-715, 1205), Posterior HDI 95%: (103, 994)
# Gravel_md_Overburden_and_interburden_owp - Navigation: 6-41-0-0, Prior HDI 95%: (-1901, 3203), Posterior HDI 95%: (388, 2622)
# Sand_pr_Concreting_Sand - Navigation: 7-13-0-0, Prior HDI 95%: (-39612, 66744), Posterior HDI 95%: (8673, 15455)
# Sand_pr_Asphalt_Sand - Navigation: 7-17-0-0, Prior HDI 95%: (-1475, 2485), Posterior HDI 95%: (374, 657)
# Sand_pr_Mortar_Sand - Navigation: 7-20-0-0, Prior HDI 95%: (-11680, 19680), Posterior HDI 95%: (1319, 2654)
# Sand_pr_Sand_for_fill - Navigation: 7-29-0-0, Prior HDI 95%: (-1837, 3095), Posterior HDI 95%: (297, 2596)
# Sand_pr_Aggregate_use - Navigation: 7-32-0-0, Prior HDI 95%: (-8415, 14179), Posterior HDI 95%: (1162, 4648)
# Sand_pr_Non-aggregate_use - Navigation: 7-33-0-0, Prior HDI 95%: (-3183, 5363), Posterior HDI 95%: (441, 1761)
# Sand_pr_Scalpings_and_Fines_owp - Navigation: 7-40-0-0, Prior HDI 95%: (-1285, 2165), Posterior HDI 95%: (22, 264)
# Sand_pr_Land_Won_Sand - Navigation: 7-42-0-0, Prior HDI 95%: (-3881, 6539), Posterior HDI 95%: (4, 31)
# 0 - Navigation: 7-43-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-5, 19)
# Sand_pr_Marine_Dredged_Sand - Navigation: 7-44-0-0, Prior HDI 95%: (-1661, 2799), Posterior HDI 95%: (3, 16)
# 0 - Navigation: 7-45-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-6, 20)
# 0 - Navigation: 7-46-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-38, 131)
# Gravel_pr_Concreting_Gravel - Navigation: 8-14-0-0, Prior HDI 95%: (-23976, 40398), Posterior HDI 95%: (6020, 10889)
# Gravel_pr_Asphalt_Gravel - Navigation: 8-18-0-0, Prior HDI 95%: (-491, 827), Posterior HDI 95%: (120, 219)
# Gravel_pr_Gravel_for_fill - Navigation: 8-30-0-0, Prior HDI 95%: (-2753, 4639), Posterior HDI 95%: (563, 4155)
# Gravel_pr_Aggregate_use - Navigation: 8-32-0-0, Prior HDI 95%: (-12626, 21274), Posterior HDI 95%: (2123, 7274)
# Gravel_pr_Non-aggregate_use - Navigation: 8-33-0-0, Prior HDI 95%: (-4777, 8049), Posterior HDI 95%: (722, 2681)
# Gravel_pr_Scalpings_and_Fines_owp - Navigation: 8-40-0-0, Prior HDI 95%: (-1930, 3252), Posterior HDI 95%: (37, 390)
# 0 - Navigation: 8-42-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-5, 18)
# Gravel_pr_Land_Won_Gravel - Navigation: 8-43-0-0, Prior HDI 95%: (-5819, 9805), Posterior HDI 95%: (4, 39)
# 0 - Navigation: 8-44-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-5, 19)
# Gravel_pr_Marine_Dredged_Gravel - Navigation: 8-45-0-0, Prior HDI 95%: (-2494, 4202), Posterior HDI 95%: (4, 22)
# 0 - Navigation: 8-46-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-38, 133)
# Crushed_Rock_pr_Concreting_Crushed_Rock - Navigation: 9-15-0-0, Prior HDI 95%: (-24644, 41524), Posterior HDI 95%: (6030, 11030)
# Crushed_Rock_pr_Asphalt_Crushed_Rock - Navigation: 9-19-0-0, Prior HDI 95%: (-7817, 13171), Posterior HDI 95%: (1900, 3459)
# 0 - Navigation: 9-24-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-189, 910)
# Crushed_Rock_pr_Crushed_Rock_for_fill - Navigation: 9-31-0-0, Prior HDI 95%: (-8877, 14957), Posterior HDI 95%: (-19, 13779)
# Crushed_Rock_pr_Aggregate_use - Navigation: 9-32-0-0, Prior HDI 95%: (-39346, 66296), Posterior HDI 95%: (9297, 18692)
# Crushed_Rock_pr_Non-aggregate_use - Navigation: 9-33-0-0, Prior HDI 95%: (-14886, 25082), Posterior HDI 95%: (3449, 6994)
# Crushed_Rock_pr_Scalpings_and_Fines_owp - Navigation: 9-40-0-0, Prior HDI 95%: (-6012, 10130), Posterior HDI 95%: (212, 1106)
# 0 - Navigation: 9-46-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-36, 131)
# Secondary_Aggregates_pr_Concreting_Sand - Navigation: 10-13-0-0, Prior HDI 95%: (-1673, 2819), Posterior HDI 95%: (172, 877)
# Secondary_Aggregates_pr_Asphalt_Sand - Navigation: 10-17-0-0, Prior HDI 95%: (-61, 103), Posterior HDI 95%: (7, 36)
# Secondary_Aggregates_pr_Mortar_Sand - Navigation: 10-20-0-0, Prior HDI 95%: (-493, 831), Posterior HDI 95%: (26, 145)
# Secondary_Aggregates_pr_Aggregate_use - Navigation: 10-32-0-0, Prior HDI 95%: (-2552, 4300), Posterior HDI 95%: (298, 1509)
# Secondary_Aggregates_pr_Non-aggregate_use - Navigation: 10-33-0-0, Prior HDI 95%: (-966, 1628), Posterior HDI 95%: (116, 559)
# Secondary_Aggregates_pr_Scalpings_and_Fines_owp - Navigation: 10-40-0-0, Prior HDI 95%: (-391, 659), Posterior HDI 95%: (4, 82)
# 0 - Navigation: 10-46-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-38, 134)
# 0 - Navigation: 11-46-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-18, 295)
# C&D_Waste_pr_Concreting_Sand - Navigation: 12-13-0-0, Prior HDI 95%: (-14506, 24442), Posterior HDI 95%: (2071, 7220)
# C&D_Waste_pr_Concreting_Gravel - Navigation: 12-14-0-0, Prior HDI 95%: (-9793, 16501), Posterior HDI 95%: (1335, 5232)
# C&D_Waste_pr_Concreting_Crushed_Rock - Navigation: 12-15-0-0, Prior HDI 95%: (-10068, 16964), Posterior HDI 95%: (1499, 5414)
# C&D_Waste_pr_Asphalt_Sand - Navigation: 12-17-0-0, Prior HDI 95%: (-540, 910), Posterior HDI 95%: (81, 297)
# C&D_Waste_pr_Asphalt_Gravel - Navigation: 12-18-0-0, Prior HDI 95%: (-199, 335), Posterior HDI 95%: (31, 108)
# C&D_Waste_pr_Asphalt_Crushed_Rock - Navigation: 12-19-0-0, Prior HDI 95%: (-3194, 5382), Posterior HDI 95%: (473, 1706)
# C&D_Waste_pr_Mortar_Sand - Navigation: 12-20-0-0, Prior HDI 95%: (-4275, 7203), Posterior HDI 95%: (286, 1185)
# 0 - Navigation: 12-24-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-189, 907)
# C&D_Waste_pr_Sand_for_fill - Navigation: 12-29-0-0, Prior HDI 95%: (-750, 1264), Posterior HDI 95%: (103, 1039)
# C&D_Waste_pr_Gravel_for_fill - Navigation: 12-30-0-0, Prior HDI 95%: (-1124, 1894), Posterior HDI 95%: (164, 1595)
# C&D_Waste_pr_Crushed_Rock_for_fill - Navigation: 12-31-0-0, Prior HDI 95%: (-3624, 6106), Posterior HDI 95%: (-89, 5312)
# C&D_Waste_pr_Aggregate_use - Navigation: 12-32-0-0, Prior HDI 95%: (-22113, 37259), Posterior HDI 95%: (6194, 8993)
# C&D_Waste_pr_Non-aggregate_use - Navigation: 12-33-0-0, Prior HDI 95%: (-8366, 14096), Posterior HDI 95%: (2339, 3390)
# C&D_Waste_pr_Scalpings_and_Fines_owp - Navigation: 12-40-0-0, Prior HDI 95%: (-3378, 5692), Posterior HDI 95%: (74, 671)
# 0 - Navigation: 12-46-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-37, 133)
# 0 - Navigation: 13-25-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (3284, 12514)
# Concreting_Sand_Buildings_Sand - Navigation: 13-26-0-0, Prior HDI 95%: (-15026, 25318), Posterior HDI 95%: (4322, 13888)
# Concreting_Sand_Manufacturing_Waste_lf - Navigation: 13-38-0-0, Prior HDI 95%: (-260, 438), Posterior HDI 95%: (-62, 437)
# Concreting_Sand_Manufacturing_Waste_owp - Navigation: 13-39-0-0, Prior HDI 95%: (-377, 635), Posterior HDI 95%: (-92, 417)
# 0 - Navigation: 14-25-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-616, 7967)
# Concreting_Gravel_Buildings_Gravel - Navigation: 14-27-0-0, Prior HDI 95%: (-22536, 37972), Posterior HDI 95%: (3186, 12586)
# Concreting_Gravel_Manufacturing_Waste_lf - Navigation: 14-38-0-0, Prior HDI 95%: (-391, 659), Posterior HDI 95%: (-93, 634)
# Concreting_Gravel_Manufacturing_Waste_owp - Navigation: 14-39-0-0, Prior HDI 95%: (-564, 950), Posterior HDI 95%: (-121, 484)
# 0 - Navigation: 15-25-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-915, 8085)
# Concreting_Crushed_Rock_Buildings_Crushed_Rock - Navigation: 15-28-0-0, Prior HDI 95%: (-70242, 118354), Posterior HDI 95%: (9735, 20362)
# Concreting_Crushed_Rock_Manufacturing_Waste_lf - Navigation: 15-38-0-0, Prior HDI 95%: (-196, 330), Posterior HDI 95%: (-47, 318)
# Concreting_Crushed_Rock_Manufacturing_Waste_owp - Navigation: 15-39-0-0, Prior HDI 95%: (-1758, 2962), Posterior HDI 95%: (-177, 611)
# 0 - Navigation: 16-25-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-1066, 7711)
# Concreting_C&D_Buildings_Crushed_Rock - Navigation: 16-28-0-0, Prior HDI 95%: (-44033, 74193), Posterior HDI 95%: (-3237, 23814)
# Concreting_C&D_Manufacturing_Waste_lf - Navigation: 16-38-0-0, Prior HDI 95%: (-123, 207), Posterior HDI 95%: (-29, 199)
# Concreting_C&D_Manufacturing_Waste_owp - Navigation: 16-39-0-0, Prior HDI 95%: (-1101, 1855), Posterior HDI 95%: (-156, 578)
# 0 - Navigation: 17-21-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (156, 1302)
# Asphalt_Sand_Manufacturing_Waste_lf - Navigation: 17-38-0-0, Prior HDI 95%: (-9, 15), Posterior HDI 95%: (-2, 14)
# Asphalt_Sand_Manufacturing_Waste_owp - Navigation: 17-39-0-0, Prior HDI 95%: (-79, 133), Posterior HDI 95%: (-20, 115)
# 0 - Navigation: 18-22-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (-98, 785)
# Asphalt_Gravel_Manufacturing_Waste_lf - Navigation: 18-38-0-0, Prior HDI 95%: (-15, 25), Posterior HDI 95%: (-4, 23)
# Asphalt_Gravel_Manufacturing_Waste_owp - Navigation: 18-39-0-0, Prior HDI 95%: (-120, 202), Posterior HDI 95%: (-32, 163)
# 0 - Navigation: 19-23-0-0, Prior HDI 95%: (nan, nan), Posterior HDI 95%: (3436, 5703)
# Asphalt_Crushed_Rock_Manufacturing_Waste_lf - Navigation: 19-38-0-0, Prior HDI 95%: (-41, 69), Posterior HDI 95%: (-10, 67)
# Asphalt_Crushed_Rock_Manufacturing_Waste_owp - Navigation: 19-39-0-0, Prior HDI 95%: (-371, 625), Posterior HDI 95%: (-89, 407)
# Mortar_Sand_Buildings_Sand - Navigation: 20-26-0-0, Prior HDI 95%: (-493, 831), Posterior HDI 95%: (600, 1810)
# Mortar_Sand_Manufacturing_Waste_lf - Navigation: 20-38-0-0, Prior HDI 95%: (-53, 89), Posterior HDI 95%: (-11, 97)
# Mortar_Sand_Manufacturing_Waste_owp - Navigation: 20-39-0-0, Prior HDI 95%: (-476, 802), Posterior HDI 95%: (191, 1239)
# Road_Sand_Demolition - Navigation: 21-35-0-0, Prior HDI 95%: (-4073, 6863), Posterior HDI 95%: (730, 3724)
# Road_Gravel_Demolition - Navigation: 22-35-0-0, Prior HDI 95%: (-6108, 10292), Posterior HDI 95%: (1138, 5587)
# Road_Crushed_Rock_Demolition - Navigation: 23-35-0-0, Prior HDI 95%: (-19038, 32078), Posterior HDI 95%: (4256, 18640)
# Railway_ballast_Demolition - Navigation: 24-35-0-0, Prior HDI 95%: (-307, 517), Posterior HDI 95%: (-51, 550)
# Other_inf_Demolition - Navigation: 25-35-0-0, Prior HDI 95%: (-49210, 82916), Posterior HDI 95%: (15760, 37882)
# Other_inf_Deconstruction - Navigation: 25-36-0-0, Prior HDI 95%: (-7601, 12807), Posterior HDI 95%: (620, 1632)
# Buildings_Sand_Demolition - Navigation: 26-35-0-0, Prior HDI 95%: (-3857, 6499), Posterior HDI 95%: (924, 3960)
# Buildings_Sand_Deconstruction - Navigation: 26-36-0-0, Prior HDI 95%: (-590, 994), Posterior HDI 95%: (25, 153)
# Buildings_Gravel_Demolition - Navigation: 27-35-0-0, Prior HDI 95%: (-5787, 9751), Posterior HDI 95%: (1211, 5626)
# Buildings_Gravel_Deconstruction - Navigation: 27-36-0-0, Prior HDI 95%: (-882, 1486), Posterior HDI 95%: (37, 227)
# Buildings_Crushed_Rock_Demolition - Navigation: 28-35-0-0, Prior HDI 95%: (-18036, 30390), Posterior HDI 95%: (4364, 18745)
# Buildings_Crushed_Rock_Deconstruction - Navigation: 28-36-0-0, Prior HDI 95%: (-2751, 4635), Posterior HDI 95%: (133, 698)
# Demolition_C&D_Waste_pr - Navigation: 35-12-0-0, Prior HDI 95%: (-100384, 169142), Posterior HDI 95%: (23640, 33902)
# Demolition_Concreting_C&D - Navigation: 35-16-0-0, Prior HDI 95%: (-21012, 35404), Posterior HDI 95%: (29, 27782)
# Demolition_C&D_Waste_lf - Navigation: 35-37-0-0, Prior HDI 95%: (-40464, 68180), Posterior HDI 95%: (-1661, 39357)
# Deconstruction_Recycled_Deconstruction_Material - Navigation: 36-11-0-0, Prior HDI 95%: (-5197, 7197), Posterior HDI 95%: (1123, 2060)
# Scalpings_and_Fines_owp_Recycled_Processing/Production_Waste - Navigation: 40-11-0-0, Prior HDI 95%: (-21549, 36309), Posterior HDI 95%: (-66, 207)
# Overburden_and_interburden_owp_Sand_for_fill - Navigation: 41-29-0-0, Prior HDI 95%: (-4771, 8039), Posterior HDI 95%: (-1149, 7307)
# Overburden_and_interburden_owp_Gravel_for_fill - Navigation: 41-30-0-0, Prior HDI 95%: (-7157, 12059), Posterior HDI 95%: (-1632, 10764)
# Overburden_and_interburden_owp_Crushed_Rock_for_fill - Navigation: 41-31-0-0, Prior HDI 95%: (-22308, 37588), Posterior HDI 95%: (-2012, 28430)
# Land_Won_Sand_Concreting_Sand - Navigation: 42-13-0-0, Prior HDI 95%: (-435, 733), Posterior HDI 95%: (72, 235)
# Land_Won_Sand_Asphalt_Sand - Navigation: 42-17-0-0, Prior HDI 95%: (-64, 108), Posterior HDI 95%: (9, 37)
# Land_Won_Sand_Mortar_Sand - Navigation: 42-20-0-0, Prior HDI 95%: (-55, 93), Posterior HDI 95%: (7, 31)
# Land_Won_Gravel_Concreting_Gravel - Navigation: 43-14-0-0, Prior HDI 95%: (-721, 1215), Posterior HDI 95%: (165, 350)
# Land_Won_Gravel_Asphalt_Gravel - Navigation: 43-18-0-0, Prior HDI 95%: (-108, 182), Posterior HDI 95%: (16, 62)
# Marine_Dredged_Sand_Concreting_Sand - Navigation: 44-13-0-0, Prior HDI 95%: (-38, 64), Posterior HDI 95%: (6, 21)
# Marine_Dredged_Sand_Asphalt_Sand - Navigation: 44-17-0-0, Prior HDI 95%: (-6, 10), Posterior HDI 95%: (1, 3)
# Marine_Dredged_Sand_Mortar_Sand - Navigation: 44-20-0-0, Prior HDI 95%: (-6, 10), Posterior HDI 95%: (1, 3)
# Marine_Dredged_Gravel_Concreting_Gravel - Navigation: 45-14-0-0, Prior HDI 95%: (-64, 108), Posterior HDI 95%: (14, 31)
# Marine_Dredged_Gravel_Asphalt_Gravel - Navigation: 45-18-0-0, Prior HDI 95%: (-9, 15), Posterior HDI 95%: (1, 5)
# Crushed_Rock_td_Concreting_Crushed_Rock - Navigation: 46-15-0-0, Prior HDI 95%: (-20264, 34144), Posterior HDI 95%: (5552, 8455)
# Crushed_Rock_td_Asphalt_Crushed_Rock - Navigation: 46-19-0-0, Prior HDI 95%: (-3040, 5122), Posterior HDI 95%: (393, 1635)
# Crushed_Rock_td_Aggregate_Use - Navigation: 46-32-0-0, Prior HDI 95%: (-2590, 4364), Posterior HDI 95%: (-606, 4273)
# Secondary_Aggregates_Secondary_Aggregates_pr - Navigation: 47-10-0-0, Prior HDI 95%: (-15563, 26223), Posterior HDI 95%: (1027, 2903)
# Marine_Dredged_Outside_England_Waters_Sand_pr - Navigation: 48-7-0-0, Prior HDI 95%: (-701, 1181), Posterior HDI 95%: (117, 369)
# Marine_Dredged_Outside_England_Waters_Gravel_pr - Navigation: 48-8-0-0, Prior HDI 95%: (-1051, 1771), Posterior HDI 95%: (226, 498)

# %%
import pandas as pd
import os
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

# Read CSV file
df = pd.read_csv('ppplots.csv')

# Create the output directory if it doesn't exist
output_directory = 'plots2019'
os.makedirs(output_directory, exist_ok=True)

# Plot prior and posterior distributions for each stock or flow
for idx, row in df.iterrows():
    # Create prior and posterior distributions
    prior_distribution = norm(loc=row['prior mean'], scale=row['prior sd'])
    posterior_distribution = norm(loc=row['mean'], scale=row['sd'])

    # Calculate 95%HDI for new data
    hdi_95_prior = norm.interval(0.95, loc=row['prior mean'], scale=row['prior sd'])
    hdi_95_posterior = norm.interval(0.95, loc=row['mean'], scale=row['sd'])

    # Plot the distributions
    plt.figure(figsize=(8, 4))
    x_values = np.linspace(min(prior_distribution.ppf(0.001), posterior_distribution.ppf(0.001)),
                           max(prior_distribution.ppf(0.999), posterior_distribution.ppf(0.999)), 100)
    
    # Plot the shaded area representing the HDI with light red for prior and light blue for posterior
    plt.fill_between(x_values, 0, prior_distribution.pdf(x_values), where=(x_values >= hdi_95_prior[0]) & (x_values <= hdi_95_prior[1]), color='lightcoral', alpha=0.2)
    plt.fill_between(x_values, 0, posterior_distribution.pdf(x_values), where=(x_values >= hdi_95_posterior[0]) & (x_values <= hdi_95_posterior[1]), color='lightblue', alpha=0.2)
    
    # Add light grey dashed lines along the sides of the shaded areas
    plt.plot([hdi_95_prior[0], hdi_95_prior[0]], [prior_distribution.pdf(hdi_95_prior[0]), prior_distribution.pdf(hdi_95_prior[1])], color='grey', linestyle='--', alpha=0.8)
    plt.plot([hdi_95_prior[1], hdi_95_prior[1]], [prior_distribution.pdf(hdi_95_prior[0]), prior_distribution.pdf(hdi_95_prior[1])], color='grey', linestyle='--', alpha=0.2)

    plt.plot([hdi_95_posterior[0], hdi_95_posterior[0]], [posterior_distribution.pdf(hdi_95_posterior[0]), posterior_distribution.pdf(hdi_95_posterior[1])], color='grey', linestyle='--')
    plt.plot([hdi_95_posterior[1], hdi_95_posterior[1]], [posterior_distribution.pdf(hdi_95_posterior[0]), posterior_distribution.pdf(hdi_95_posterior[1])], color='grey', linestyle='--')
     
    # Plot the distribution curves
    plt.plot(x_values, prior_distribution.pdf(x_values), label='Prior', color='r')
    plt.plot(x_values, posterior_distribution.pdf(x_values), label='Posterior', color='steelblue')
    
    # Add filled circles for 'mean' and 'prior mean' on the x-axis
    plt.scatter([row['prior mean'], row['mean']], [0, 0], c=['r', 'steelblue'], marker='o', s=35, zorder=10, clip_on=False)
    
    #means
    mean_label = f"Mean = {row['mean']:.0f}"
    prior_mean_label = f'Prior Mean: {row["prior mean"]:.0f}'
    # Add text annotations
    plt.text(0.02, 0.92, mean_label, ha='left', va='center', transform=plt.gca().transAxes, bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))
    plt.text(0.02, 0.84, prior_mean_label, ha='left', va='center', transform=plt.gca().transAxes, bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))

    
    # Hide y-axis ticks and labels
    plt.tick_params(axis='y', which='both', left=False, right=False, labelleft=False)
    
    plt.title(f'{row["name"]}')
    plt.xlabel('Quantity (thousand tonnes)', labelpad=10)
    plt.ylabel('Density')
    plt.xticks(rotation=45, ha="right")
    
    # Customize legend box
    legend = plt.legend(loc='upper right')
    legend.get_frame().set_edgecolor('none')
    
    # Add faint grid lines (major and minor)
    plt.grid(which='both', linestyle='-', linewidth='0.1', color='grey', alpha=0.8)
    
    # Set y-axis limits to ensure circles are on the x-axis
    plt.ylim(bottom=0)
    
    # Adjust plot area
    plt.tight_layout()
    
    # Save the plot as a PNG file with an arbitrary name
    output_path = os.path.join(output_directory, f'{idx + 1}.png')
    plt.savefig(output_path)
    plt.close()

# Display all the plots after the loop is completed
plt.show()
